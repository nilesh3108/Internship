# %% [markdown]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
#
# You need to find following details:
#
# A) Rank
#
# B) Name
#
# C) Artist
#
# D) Upload date
#
# E) Views

# %%
# import necessary libraries at once

import pandas as pd
import selenium
import time
from bs4 import BeautifulSoup 
from selenium import webdriver
from selenium.webdriver.common.by import By

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import requests
import re
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %%
driver=webdriver.Chrome('chromedriver.exe')

# Getting the webpage of url 

url=('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')
driver.get(url)

# %%
# Creating empty list for storing data after scraping

Rank = []
Name = []
Artist = []
UploadDate = []
Views = []


# Scraping Rank of the videos
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]"):
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append("_")
    
    
#scrapping rank
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]"):
        Name.append(i.text)
except NoSuchElementException:
    Name.append("_")
    
    
#scrapping Artist
try:
    for i in driver.find_elements(By.XPATH,'//*[@id="mw-content-text"]/div[1]/table[2]/tbody/tr/td[3]'):
        Artist.append(i.text)
except NoSuchElementException:
    Artist.append("_")
    
    
#Scrapping Date
try:
    for i in driver.find_elements(By.XPATH,' //table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[5]'):
        UploadDate.append(i.text)
except NoSuchElementException:
    UploadDate.append('-')
# Scraping Views of videos


try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]"):
        Views.append(i.text)
except NoSuchElementException:
    Views.append("_")

# %%
# Creating DataFrame from scraped data
wikipedia = pd.DataFrame({})
wikipedia['Rank']=Rank
wikipedia['Name']=Name
wikipedia['Artist']=Artist
wikipedia['Upload Date']=UploadDate
wikipedia['Views']=Views

# %%
wikipedia
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.                "Phonics Song with Two Words"[21]
# 7    8.                                "Uptown Funk"[22]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[23]
# 9   10.                              "Gangnam Style"[24]
# 10  11.   "Masha and the Bear – Recipe for Disaster"[29]
# 11  12.                          "Wheels on the Bus"[30]
# 12  13.                             "Dame Tu Cosita"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# 15  16.                             "Counting Stars"[34]
# 16  17.                                      "Sorry"[35]
# 17  18.                                     "Axel F"[36]
# 18  18.                          "Thinking Out Loud"[37]
# 19  20.                        "Baa Baa Black Sheep"[38]
# 20  21.                                 "Dark Horse"[39]
# 21  22.                                      "Faded"[40]
# 22  23.                             "Girls Like You"[41]
# 23  24.                                 "Let Her Go"[42]
# 24  25.                                   "Bailando"[43]
# 25  26.                                    "Lean On"[44]
# 26  27.                                    "Perfect"[45]
# 27  28.           "Waka Waka (This Time for Africa)"[46]
# 28  29.                               "Shake It Off"[47]
# 29  30.          "Humpty the train on a fruits ride"[48]
#
#                                            Artist        Upload Date  Views
# 0     Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016  11.30
# 1                                      Luis Fonsi   January 12, 2017   7.97
# 2                                     LooLoo Kids    October 8, 2016   6.45
# 3                                      Ed Sheeran   January 30, 2017   5.80
# 4                                     Wiz Khalifa      April 6, 2015   5.63
# 5                      Cocomelon – Nursery Rhymes        May 2, 2018   5.60
# 6                                       ChuChu TV      March 6, 2014   4.87
# 7                                     Mark Ronson  November 19, 2014   4.68
# 8                                     Miroshka TV  February 27, 2018   4.61
# 9                                             Psy      July 15, 2012   4.54
# 10                                     Get Movies   January 31, 2012   4.51
# 11                     Cocomelon – Nursery Rhymes       May 24, 2018   4.34
# 12                                      El Chombo      April 5, 2018   4.06
# 13                                       Maroon 5   January 14, 2015   3.75
# 14                                     Katy Perry  September 5, 2013   3.65
# 15                                    OneRepublic       May 31, 2013   3.64
# 16                                  Justin Bieber   October 22, 2015   3.58
# 17                                     Crazy Frog      June 16, 2009   3.50
# 18                                     Ed Sheeran    October 7, 2014   3.49
# 19                     Cocomelon – Nursery Rhymes      June 25, 2018   3.36
# 20                                     Katy Perry  February 20, 2014   3.34
# 21                                    Alan Walker   December 3, 2015   3.34
# 22                                       Maroon 5       May 31, 2018   3.33
# 23                                      Passenger      July 25, 2012   3.29
# 24                               Enrique Iglesias     April 11, 2014   3.26
# 25                                    Major Lazer     March 22, 2015   3.26
# 26                                     Ed Sheeran   November 9, 2017   3.25
# 27                                        Shakira       June 4, 2010   3.24
# 28                                   Taylor Swift    August 18, 2014   3.20
# 29  Kiddiestv Hindi – Nursery Rhymes & Kids Songs   January 26, 2018   3.15

# %%
driver.close()

# %% [markdown]
# 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
#
# You need to find following details:
#
# A) Match title (I.e. 1st ODI)
#
# B) Series
#
# C) Place
#
# D) Date
#
# E) Time
#
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
#connect to webdriver
driver=webdriver.Chrome("chromedriver.exe")
driver.maximize_window()

#get webpage
url=("https://www.bcci.tv/")
driver.get(url)
time.sleep(2)

# %%
#clicking on menu
button= driver.find_element(By.XPATH,'//span[@class = "menu-icon__line menu-icon__line-right"]').get_attribute('href')

# %%
#selecting International
International= driver.find_element(By.XPATH,'//a[@class = "nav-link "]').click()

# %%
#clicking on dropdown
Select= driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[2]/div/div[3]/div/div[1]').click()

# %%
#selecting ODI
OdI= driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[2]/div/div[3]/div/div[2]/div[3]').click()

# %%
Match_title= []
Series= []
Place= []
Date= []
Time= []

#scraping Match Title
try:
    Match_title_tag= driver.find_elements(By.XPATH,"//div[@class='fixture-card-top']/h5[2]")
    for i in Match_title_tag:
        Match_title.append(i.text)
except NoSuchElementException as e:
    Match_title.append("--")

#scraping Series
try:
    Series_tag= driver.find_elements(By.XPATH,"//div[@class='fixture-card-bottom']")
    for i in Series_tag:
        Series.append(i.text.split("-")[0])
except NoSuchElementException as e:
    Series.append("--")
    
#scraping Place
try:
    Place_tag= driver.find_elements(By.XPATH,"//div[@class='fixture-card-bottom']")
    for i in Place_tag:
        Place.append(i.text.split("-")[1].replace("\n",","))
except NoSuchElementException as e:
    Place.append("--") 

#scraping Date
try:
    Date_tag= driver.find_elements(By.XPATH,"//div[@class='match-card-left match-schedule']")
    for i in Date_tag:
        Date.append(i.text)
except NoSuchElementException as e:
    Date.append("--")

#scraping Time   
try:
    Time_tag= driver.find_elements(By.XPATH,"//div[@class='match-card-right match-schedule ']")
    for i in Time_tag:
        Time.append(i.text)
except NoSuchElementException as e:
    Time.append("--")

#printing length
print(len(Match_title),len(Series),len(Place),len(Date),len(Time))

#creating Dataframe
international_fixtures=pd.DataFrame({"Match_title":Match_title,"Series":Series,"Place":Place,"Date":Date,"Time":Time})
international_fixtures
# Out:
# 6 6 6 6 6
#                                      Match_title    Series  \
# 0    INDIA WOMEN TOUR OF ENGLAND ODI SERIES 2022  1st ODI
# 1    INDIA WOMEN TOUR OF ENGLAND ODI SERIES 2022  2nd ODI
# 2    INDIA WOMEN TOUR OF ENGLAND ODI SERIES 2022  3rd ODI
# 3  SOUTH AFRICA TOUR OF INDIA ODI SERIES 2022-23  1st ODI
# 4  SOUTH AFRICA TOUR OF INDIA ODI SERIES 2022-23  2nd ODI
# 5  SOUTH AFRICA TOUR OF INDIA ODI SERIES 2022-23  3rd ODI
#
#                                                Place         Date         Time
# 0                   County Ground, Hove,Match Centre  18 SEP 2022  3:30 PM IST
# 1        St Lawrence Ground, Canterbury,Match Centre  21 SEP 2022  5:30 PM IST
# 2         Lord's Cricket Ground, London,Match Centre  24 SEP 2022  3:30 PM IST
# 3   Bharat Ratna Shri Atal Bihari Vajpayee Ekana ...   6 OCT 2022  1:30 PM IST
# 4   JSCA International Stadium Complex, Ranchi,Ma...   9 OCT 2022  1:30 PM IST
# 5           Arun Jaitley Stadium, Delhi,Match Centre  11 OCT 2022  1:30 PM IST

# %%
driver.close()

# %% [markdown]
# 3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
#
# You need to find following details:
#
# A) Name
#
# B) Description
#
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
#connect to webdriver
driver=webdriver.Chrome(r'chromedriver.exe')
driver.maximize_window()

#get webpage
url=("https://www.guru99.com/")
driver.get(url)
time.sleep(2)

# %%
# Click Selenium Button
Selenium = driver.find_element(By.XPATH,'//div[@class = "wp-block-kadence-column inner-column-2 kadence-column_f38d98-3a"]') # click button
try:
    Selenium.click()
except ElementNotInteractableException:#handling element not clickable exception
    driver.get(Selenium.get_attribute('href'))

# %%
# Click selenium exception handling  Button
exception_handling = driver.find_element(By.XPATH,"//a[@title='Selenium Exception Handling (Common Exceptions List)']")
try:
    exception_handling.click()
except ElementNotInteractableException:  #if the above code doesn't work/is not clickable then, the below code will handle it
    driver.get(exception_handling.get_attribute('href'))

# %%
# Scrape all names tag
names=[]
try:
    name=driver.find_elements(By.XPATH,"//table[@class='table table-striped']/tbody/tr/td[1]")
    for i in name[1:]:
        names.append(i.text)
except NoSuchElementException:
    names.append('N/A')

# %%
# Scrape all Description tag

desc=[]
try:
    descrip=driver.find_elements(By.XPATH,"//table[@class='table table-striped']/tbody/tr/td[2]")
    for i in descrip[1:]:
        desc.append(i.text)
except NoSuchElementException:
    desc.append('No details available')

# %%
#create Dataframe

dataframe=pd.DataFrame()
dataframe['Exception name']=names
dataframe['Description']=desc
print('\033[1m'+'Selenium Exception from Guru 99 :'+'\033[0m')
dataframe
# Out:
# Selenium Exception from Guru 99 :
# Empty DataFrame
# Columns: [Exception name, Description]
# Index: []

# %%
driver.close()

# %% [markdown]
# 4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
#
# You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP(18-19)
#
# D) GSDP(17-18)
#
# E) Share(2017)
#
# F) GDP($ billion)
#
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
# connect to webdriver
driver=webdriver.Chrome(r'chromedriver.exe')
driver.maximize_window()

# get webpage
url=("https://www.statisticstimes.com/")
driver.get(url)
time.sleep(2)

# %%
# click Economy button

economy = driver.find_element(By.XPATH,"//*[@id='top']/div[2]/div[2]/button")
try:
    economy.click()
except ElementNotInteractableException:
    driver.get(economy.get_attribute('href'))

# %%
# click on GDP and and go to GDP page

gdp = driver.find_element(By.XPATH,"//*[@id='top']/div[2]/div[2]/div/a[3]")
try:
    gdp.click()
except ElementNotInteractableException:
    driver.get(gdp.get_attribute('href'))

# %%
# click on GDP of Indian State

gdp_state = driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[2]/ul/li[1]/a")
try:
    gdp_state.click()
except ElementNotInteractableException:
    driver.get(gdp_state.get_attribute('href'))

# %%
Rank= []
State= []
GSDP_2019= []
GSDP_2018= []
Share_2017= []
GDP= []

#scraping Rank
try:
    Rank_tag=driver.find_elements(By.XPATH,"//*[@id='table_id']/tbody/tr/td[1]")
    for i in Rank_tag:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')
except StaleElementReferenceException:
    Rank.append('--')

#scraping State
try:
    State_tag=driver.find_elements(By.XPATH,"//*[@id='table_id']/tbody/tr/td[2]")
    for i in State_tag:
        State.append(i.text)
except NoSuchElementException:
    State.append('-')
except StaleElementReferenceException:
    State.append('--')

#scraping GSDP 2019
try:
    GSDP_2019_tag=driver.find_elements(By.XPATH,"//*[@id='table_id']/tbody/tr/td[3]")
    for i in GSDP_2019_tag:
        GSDP_2019.append(i.text)
except NoSuchElementException:
    GSDP_2019.append('-')
except StaleElementReferenceException:
    GSDP_2019.append('--')
    
#scraping GSDP 2018
try:
    GSDP_2018_tag=driver.find_elements(By.XPATH,"//*[@id='table_id']/tbody/tr/td[4]")
    for i in GSDP_2018_tag:
        GSDP_2018.append(i.text)
except NoSuchElementException:
    GSDP_2018.append('-')
except StaleElementReferenceException:
    GSDP_2018.append('--')
    
#scraping share 2017
try:
    Share_2017_tag=driver.find_elements(By.XPATH,"//*[@id='table_id']/tbody/tr/td[5]")
    for i in Share_2017_tag:
        Share_2017.append(i.text)
except NoSuchElementException:
    Share_2017.append('-')
except StaleElementReferenceException:
    Share_2017.append('--')

#scraping GDP
try:
    GDP_tag=driver.find_elements(By.XPATH,"//*[@id='table_id']/tbody/tr/td[6]")
    for i in GDP_tag:
        GDP.append(i.text)
except NoSuchElementException:
    GDP.append('-')
except StaleElementReferenceException:
    GDP.append('--')
    
#printing length
print(len(Rank),len(State),len(GSDP_2019),len(GSDP_2018),len(Share_2017),len(GDP))

#creating Dataframe
State_GDP=pd.DataFrame({"Rank":Rank,"State":State,"GSDP_2019":GSDP_2019,"GSDP_2018":GSDP_2018,"Share_2017":Share_2017,"GDP":GDP}).set_index('Rank')
State_GDP
# Out:
# 33 33 33 33 33 33
#                           State  GSDP_2019  GSDP_2018 Share_2017      GDP
# Rank
# 1                   Maharashtra          -  2,632,792     13.94%  399.921
# 2                    Tamil Nadu  1,845,853  1,630,208      8.63%  247.629
# 3                 Uttar Pradesh  1,687,818  1,584,764      8.39%  240.726
# 4                       Gujarat          -  1,502,899      7.96%  228.290
# 5                     Karnataka  1,631,977  1,493,127      7.91%  226.806
# 6                   West Bengal  1,253,832  1,089,898      5.77%  165.556
# 7                     Rajasthan  1,020,989    942,586      4.99%  143.179
# 8                Andhra Pradesh    972,782    862,957      4.57%  131.083
# 9                     Telangana    969,604    861,031      4.56%  130.791
# 10               Madhya Pradesh    906,672    809,592      4.29%  122.977
# 11                       Kerala          -    781,653      4.14%  118.733
# 12                        Delhi    856,112    774,870      4.10%  117.703
# 13                      Haryana    831,610    734,163      3.89%  111.519
# 14                        Bihar    611,804    530,363      2.81%   80.562
# 15                       Punjab    574,760    526,376      2.79%   79.957
# 16                       Odisha    521,275    487,805      2.58%   74.098
# 17                        Assam          -    315,881      1.67%   47.982
# 18                 Chhattisgarh    329,180    304,063      1.61%   46.187
# 19                    Jharkhand    328,598    297,204      1.57%   45.145
# 20                  Uttarakhand          -    245,895      1.30%   37.351
# 21              Jammu & Kashmir          -    155,956      0.83%   23.690
# 22             Himachal Pradesh    165,472    153,845      0.81%   23.369
# 23                          Goa     80,449     73,170      0.39%   11.115
# 24                      Tripura     55,984     49,845      0.26%    7.571
# 25                   Chandigarh          -     42,114      0.22%    6.397
# 26                   Puducherry     38,253     34,433      0.18%    5.230
# 27                    Meghalaya     36,572     33,481      0.18%    5.086
# 28                       Sikkim     32,496     28,723      0.15%    4.363
# 29                      Manipur     31,790     27,870      0.15%    4.233
# 30                     Nagaland          -     27,283      0.14%    4.144
# 31            Arunachal Pradesh          -     24,603      0.13%    3.737
# 32                      Mizoram     26,503     22,287      0.12%    3.385
# 33    Andaman & Nicobar Islands          -          -          -        -

# %%
driver.close()

# %% [markdown]
# 5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
#
# You have to find the following details:
#
# A) Repository title
#
# B) Repository description
#
# C) Contributors count
#
# D) Language used
#
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
#connect to webdriver
driver=webdriver.Chrome(r'chromedriver.exe')
driver.maximize_window()

#get webpage
url=(" https://github.com/")
driver.get(url)
time.sleep(2)

# %%
# Clicking on Trending under explore sub menu
trending = driver.find_element(By.XPATH,'//*[@href="/trending"]')
try:
    driver.get(trending.get_attribute('href'))
except ElementNotInteractableException:
    driver.get(trending.get_attribute('href'))

# %%
Repository_title= []
Repository_description= []
Contributors_count= []
Language_used= []
urls=[]

#Scraping title of repository
try:
    Repository_title_tag=driver.find_elements(By.XPATH,'//article[@class="Box-row"]/h1/a')
    for i in Repository_title_tag:
        Repository_title.append(i.text)
except NoSuchElementException:
    Repository_title.append('-')
    
#Scraping description of Repository
try:
    description=driver.find_elements(By.XPATH,'//article[@class="Box-row"]/p')
    for i in description:
        Repository_description.append(i.text)
except NoSuchElementException:
    Repository_description.append('-')

for i in [Repository_title_tag,description]:
    for j in i:
        if i ==Repository_title_tag:
            Repository_title.append(j.text)
            urls.append(j.get_attribute('href'))
        if i==description:
            Repository_description.append(j.text)
    
for url in urls:
    driver.get(url)
    driver.implicitly_wait(3)
    div_list=driver.find_elements(By.XPATH,'//div[@class="BorderGrid BorderGrid--spacious"]/div')
    #Scraping count of contributors   
    try:
        Contributors_count.append(((div_list[-2].text).split())[1])
    except:
        Contributors_count.append('-')
    #Scraping used language
    try:
        Language_used.append(((div_list[-1].text).split())[1::2])
    except:
        Language_used.append('-')
        
#printing length
len(Repository_title),len(Repository_description),len(Language_used),len(Contributors_count)

#creating Dataframe
github_trending=pd.DataFrame({"Repository_title":Repository_title[:25],"Repository_description":Repository_description[:25],"Language_used":Language_used[:25],"Contributors_count":Contributors_count[:25]})
github_trending
# Out:
#                                      Repository_title  \
# 0                             pocketbase / pocketbase
# 1                                   alura / techguide
# 2                                danielgindi / Charts
# 3                     ethereum / ethereum-org-website
# 4                         revanced / revanced-manager
# 5                            remix-run / react-router
# 6                            PaddlePaddle / PaddleHub
# 7                                  malwaredllc / byob
# 8                               surrealdb / surrealdb
# 9                                   ascoders / weekly
# 10                            hoppscotch / hoppscotch
# 11  YangLing0818 / Diffusion-Models-Papers-Survey-...
# 12                                      dotnet / core
# 13                              Alamofire / Alamofire
# 14                         protocolbuffers / protobuf
# 15                  cloud-custodian / cloud-custodian
# 16                              SerenityOS / ladybird
# 17        joaocarvalhoopen / How_to_learn_modern_Rust
# 18                             microsoft / playwright
# 19                                            d3 / d3
# 20                                  LSPosed / LSPosed
# 21                                OpenEthan / SMSBoom
# 22                           Azure / azure-sdk-for-js
# 23                                  CocoaPods / Specs
# 24                                      google / glog
#
#                                Repository_description  \
# 0              Open Source realtime backend in 1 file
# 1   TechGuide main repository with the code that g...
# 2   Beautiful charts for iOS/tvOS/OSX! The Apple s...
# 3   Ethereum.org is a primary online resource for ...
# 4                     💊 The official ReVanced Manager
# 5                       Declarative routing for React
# 6   Awesome pre-trained models toolkit based on Pa...
# 7   An open-source post-exploitation framework for...
# 8   A scalable, distributed, collaborative, docume...
# 9                               前端精读周刊。帮你理解最前沿、实用的技术。
# 10  👽 Open source API development ecosystem - http...
# 11       Diffusion model papers, survey, and taxonomy
# 12                      Home repository for .NET Core
# 13                   Elegant HTTP Networking in Swift
# 14  Protocol Buffers - Google's data interchange f...
# 15  Rules engine for cloud security, cost optimiza...
# 16                               Ladybird web browser
# 17                         A guide to the adventurer.
# 18  Playwright is a framework for Web Testing and ...
# 19  Bring data to life with SVG, Canvas and HTML. 📊📈🎉
# 20                                  LSPosed Framework
# 21  短信轰炸/短信测压/ | 一个健壮免费的python短信轰炸程序，专门炸坏蛋蛋，百万接口，多...
# 22  This repository is for active development of t...
# 23                          The CocoaPods Master Repo
# 24    C++ implementation of the Google logging module
#
#                                         Language_used Contributors_count
# 0         [Go, Svelte, SCSS, JavaScript, HTML, Shell]                 15
# 1                            [TypeScript, JavaScript]                  8
# 2                         [Swift, Objective-C, Other]                150
# 3                              [Markdown, TypeScript]                919
# 4                                      [Dart, Kotlin]                  5
# 5                            [TypeScript, JavaScript]                775
# 6                                     [Python, Other]                 57
# 7                          [Python, HTML, Shell, PHP]                 28
# 8                                       [Rust, Other]                 11
# 9                                        [JavaScript]                 67
# 10                [Vue, TypeScript, JavaScript, SCSS]                193
# 11                                                 []                 No
# 12                                [PowerShell, Shell]                302
# 13                                            [Swift]                240
# 14     [C++, C#, Java, Objective-C, C, Python, Other]                880
# 15          [Python, Go, HCL, Jinja, Shell, Makefile]                353
# 16                                 [C++, CMake, Java]                 16
# 17                                                 []                 No
# 18  [TypeScript, HTML, C++, CSS, JavaScript, Objec...                295
# 19                                       [JavaScript]                123
# 20          [Java, C++, Kotlin, CSS, Shell, C, Other]                 62
# 21             [Python, JavaScript, HTML, Dockerfile]                 13
# 22  [TypeScript, JavaScript, PowerShell, Shell, HT...                358
# 23                                   [5,000+, 32,360]                  -
# 24                      [C++, CMake, Starlark, Shell]                115

# %%
driver.close()

# %% [markdown]
# 6. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
#
# You have to find the following details:
#
# A) Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board
#
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
#connect to webdriver
driver=webdriver.Chrome(r'chromedriver.exe')
driver.maximize_window()

#get webpage
url=("https://www.billboard.com")
driver.get(url)
time.sleep(2)

# %%
#Clicking on hot 100
url=driver.find_elements(By.XPATH,"//a[@class='c-link  lrv-a-unstyle-link lrv-u-font-size-18@desktop lrv-u-color-grey:hover u-color-brand-secondary:hover@desktop-max u-padding-a-1@desktop-max lrv-u-padding-tb-025 lrv-u-display-block']")
urls=url[0].get_attribute('href')
driver.get(urls)

# %%
#Clicking on hot 100
clickk= driver.find_element(By.XPATH,'/html/body/div[3]/main/div[2]/div[3]/div/div/div[2]/div/div[1]/a')
clickk.click()
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# Input In [31], in <cell line: 3>()
#       1 #Clicking on hot 100
#       2 clickk= driver.find_element(By.XPATH,'/html/body/div[3]/main/div[2]/div[3]/div/div/div[2]/div/div[1]/a')
# ----> 3 clickk.click()
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:88, in WebElement.click(self)
#      86 def click(self) -> None:
#      87     """Clicks the element."""
# ---> 88     self._execute(Command.CLICK_ELEMENT)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:396, in WebElement._execute(self, command, params)
#     394     params = {}
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
#     429     response['value'] = self._unwrap_value(
#     430         response.get('value', None))
#     431     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# ElementClickInterceptedException: Message: element click intercepted: Element is not clickable at point (388, 3549)
#   (Session info: chrome=105.0.5195.102)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x007478B3+2193587]
# 	Ordinal0 [0x006E0681+1771137]
# 	Ordinal0 [0x005F41A8+803240]
# 	Ordinal0 [0x00628C84+1019012]
# 	Ordinal0 [0x00626C48+1010760]
# 	Ordinal0 [0x0062493B+1001787]
# 	Ordinal0 [0x00623699+997017]
# 	Ordinal0 [0x00619223+954915]
# 	Ordinal0 [0x0063D7AC+1103788]
# 	Ordinal0 [0x00618C04+953348]
# 	Ordinal0 [0x0063D9C4+1104324]
# 	Ordinal0 [0x0064DAE2+1170146]
# 	Ordinal0 [0x0063D5C6+1103302]
# 	Ordinal0 [0x006177E0+948192]
# 	Ordinal0 [0x006186E6+952038]
# 	GetHandleVerifier [0x009F0CB2+2738370]
# 	GetHandleVerifier [0x009E21B8+2678216]
# 	GetHandleVerifier [0x007D17AA+512954]
# 	GetHandleVerifier [0x007D0856+509030]
# 	Ordinal0 [0x006E743B+1799227]
# 	Ordinal0 [0x006EBB68+1817448]
# 	Ordinal0 [0x006EBC55+1817685]
# 	Ordinal0 [0x006F5230+1856048]
# 	BaseThreadInitThunk [0x767EFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77347A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77347A6E+238]

# %%
#Scrap all tags

Name=[]
Name.append(driver.find_element(By.XPATH,"//span[@class='c-label  a-font-primary-medium-l u-letter-spacing-0021']").text)
Artist=[]
Artist.append(driver.find_element(By.XPATH,"//span[@class='c-label  a-font-primary-s u-letter-spacing-0021']").text)
rank=[]
rankTag=driver.find_elements(By.XPATH,"//span[@class='c-label  a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@tablet']")
rank.extend([i.text for i in rankTag[:3]])

# %%
#Scrap all tags
nameTag=driver.find_elements(By.XPATH,"//h3[@class='c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only']")
Name.extend([i.text for i in nameTag])
artistTag=driver.find_elements(By.XPATH,"//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only']")
Artist.extend([i.text for i in artistTag])
Rank=[]
RankTag=driver.find_elements(By.XPATH,"//span[@class='c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max']")
Rank.extend([i.text for i in RankTag])

# %%
# removing ''
for i in Rank:
    if i=='':
        Rank.remove(i)

# %%
# slicing Data
last_week_rank=Rank[0::3]
last_week_rank.insert(0,rank[0])
peak_rank=Rank[1::3]
peak_rank.insert(0,rank[1])
weeks_on_board=Rank[2::3]
weeks_on_board.insert(0,rank[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [35], in <cell line: 3>()
#       1 # slicing Data
#       2 last_week_rank=Rank[0::3]
# ----> 3 last_week_rank.insert(0,rank[0])
#       4 peak_rank=Rank[1::3]
#       5 peak_rank.insert(0,rank[1])
#
# IndexError: list index out of range

# %%
#check length of all
len(Name),len(Artist),len(last_week_rank),len(peak_rank),len(weeks_on_board)
# Out:
# (1, 1, 0, 0, 0)

# %%
# Create Dataframe
df=pd.DataFrame()
df['SongName']=Name
df['ArtistName']=Artist
df['Last Week']=last_week_rank[0:100]
df["PeekPosition"]=peak_rank[0:100]
df['Weeks On board']=weeks_on_board[0:100]
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [37], in <cell line: 5>()
#       3 df['SongName']=Name
#       4 df['ArtistName']=Artist
# ----> 5 df['Last Week']=last_week_rank[0:100]
#       6 df["PeekPosition"]=peak_rank[0:100]
#       7 df['Weeks On board']=weeks_on_board[0:100]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
#    3836         and value.ndim == 1
#    3837         and not is_extension_array_dtype(value)
#    3838     ):
#    3839         # broadcast across multiple columns if necessary
#    3840         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4535, in DataFrame._sanitize_column(self, value)
#    4532     return _reindex_for_setitem(value, self.index)
#    4534 if is_list_like(value):
# -> 4535     com.require_length_match(value, self.index)
#    4536 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\common.py:557, in require_length_match(data, index)
#     553 """
#     554 Check the length of data matches the length of the index.
#     555 """
#     556 if len(data) != len(index):
# --> 557     raise ValueError(
#     558         "Length of values "
#     559         f"({len(data)}) "
#     560         "does not match length of index "
#     561         f"({len(index)})"
#     562     )
#
# ValueError: Length of values (0) does not match length of index (1)

# %% [markdown]
# 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
#
# You have to find the following details:
#
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they hire for
#
# E) Location
#
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code

# %%
#connect to webdriver
driver=webdriver.Chrome(r'chromedriver.exe')
driver.maximize_window()

#get webpage
url=("https://www.naukri.com/hr-recruiters-consultants")
driver.get(url)
time.sleep(2)

# %%
#click on Browse All Recruiters
browse= driver.find_element(By.XPATH,"//a[@title='Search Recruiters']").get_attribute("href")
driver.get(browse)

#Search for Data Science Recruiters
driver.find_element(By.XPATH,"//input[@class='sugInp']").send_keys("Data Science")
driver.find_element(By.XPATH,"//button[@class='fl qsbSrch blueBtn']").click()

# %%
Name= []
Designation= []
Company= []
Skills= []
Location= []

#scraping Recruiters Name
try:
    Name_tag=driver.find_elements(By.XPATH,"//span[@class='fl ellipsis']")
    for i in Name_tag:
        Name.append(i.text)
except:
    Name.append("-")
    
#scraping Designation    
try:
    Designation_tag=driver.find_elements(By.XPATH,"//span[@class='ellipsis clr']")
    for i in Designation_tag:
        Designation.append(i.text)
except:
    Designation.append("-")

#scraping company    
try:
    Company_tag=driver.find_elements(By.XPATH,"//a[@class='ellipsis']")[1::2]
    for i in Company_tag:
        Company.append(i.text)
except:
    Company.append("-")
    
#scraping skills    
try:
    Skills_tag=driver.find_elements(By.XPATH,"//div[@class='hireSec highlightable']")
    for i in Skills_tag:
        Skills.append(i.text)
except:
    Skills.append("-")

#scraping Location
try:
    Location_tag=driver.find_elements(By.XPATH,"//small[@class='ellipsis']")
    for i in Location_tag:
            Location.append(i.text)
except:
        Location.append("-")

#printing length
print(len(Name), len(Designation),len(Company), len(Skills), len(Location))
# Out:
# 50 50 50 50 48

# %%
#creating Dataframe
recruiters=pd.DataFrame({"Name":Name[:48],"Designation":Designation[:48],"Company":Company[:48],"Skills":Skills[:48],"Location":Location})
recruiters
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                 Priyanka Akiri
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                             Vaishnavi Kudalkar
# 15                             Mahesh Babu Channa
# 16                                   Kapil Devang
# 17                                Sakshi Chhikara
# 18                                    Ruchi Dhote
# 19                                  Manisha Yadav
# 20                                    Riya Rajesh
# 21                           Rashmi Bhattacharjee
# 22                                  Faizan Kareem
# 23                                 Rithika dadwal
# 24                             Sandhya Khandagale
# 25                                      Shaun Rao
# 26                                  Azahar Shaikh
# 27                                          Manas
# 28                                          kumar
# 29                                   Sunil Vedula
# 30                                    Rajat Kumar
# 31                                Dhruv Dev Dubey
# 32                                      Jayanth N
# 33                                         Avodha
# 34                                    Priya Khare
# 35                                    Amit Sharma
# 36                                          Kanan
# 37                           Shashikant Chaudhary
# 38                                           Brad
# 39                                   Rutuja Pawar
# 40                            Madhusudhan Sridhar
# 41                                    Ankit Sinha
# 42                                 Gaurav Chouhan
# 43                                   Rashi Kacker
# 44                                        Ashwini
# 45                                   Balaji Kolli
# 46                                 Rajani Nagaraj
# 47                                    ROHIT Kumar
#
#                             Designation  \
# 0                            HR Manager
# 1                     Company Recruiter
# 2                            Company HR
# 3                     Company Recruiter
# 4                           Founder CEO
# 5           Recruitment Lead Consultant
# 6                     Programme Manager
# 7                      HR Administrator
# 8                              Director
# 9                        Human Resource
# 10                           HR Manager
# 11                     Executive Hiring
# 12                           Company HR
# 13                           Company HR
# 14                         HR Executive
# 15                         HR Team Lead
# 16                           HR Manager
# 17                 Assistant Manager HR
# 18  Senior Executive Talent Acquisition
# 19                         HR Executive
# 20           Manager Talent Acquisition
# 21                              HR Head
# 22                           HR MANAGER
# 23                         HR Recruiter
# 24                         HR Recruiter
# 25              Manager Human Resources
# 26                    Company Recruiter
# 27              Lead Talent acquisition
# 28                           Proprietor
# 29                                  CEO
# 30                          Founder CEO
# 31             Company Recruitment Head
# 32                      Project Manager
# 33       Business Development Associate
# 34                       Senior Manager
# 35                           Consultant
# 36         senior technology instructor
# 37             HR Recruiter/HR Excutive
# 38        Manager, Technical Recruiting
# 39                  Technical Recruiter
# 40                      Erp Implementer
# 41                       Head Analytics
# 42              Chief Technical Officer
# 43                   Sr Product Manager
# 44             Director Global Delivery
# 45                           Co Founder
# 46                           HR Manager
# 47                            Architect
#
#                                            Company  \
# 0                             Data Science Network
# 1                    Shore Infotech India Pvt. Ltd
# 2                         MARSIAN Technologies LLP
# 3            Enerlytics Software Solutions Pvt Ltd
# 4                                  LibraryXProject
# 5       Apidel Technologies Division of Transpower
# 6                                             IFMR
# 7                      Techvantage Systems Pvt Ltd
# 8                       Weupskill- Live Wire India
# 9                 CBL Data Science Private Limited
# 10                   Infinitive Software Solutions
# 11                              Innominds Software
# 12                                        MoneyTap
# 13              QuantMagnum Technologies Pvt. Ltd.
# 14                             Codeachive learning
# 15                               SocialPrachar.com
# 16                                  BISP Solutions
# 17                   BIZ INFOTECNO PRIVATE LIMITED
# 18                           Bristlecone India Ltd
# 19                                        Easi Tax
# 20                     Novelworx Digital Solutions
# 21         AXESTRACK SOFTWARE SOLUTIONS PRIVATE...
# 22                   FirstTech Consaltants Pvt.Ltd
# 23                                Affine Analytics
# 24                 Compumatrice Multimedia Pvt Ltd
# 25                              Exela Technologies
# 26                 NEAL ANALYTICS SERVICES PVT LTD
# 27      Autumn Leaf Consulting Services Private...
# 28                                         trainin
# 29                            Nanoprecise Sci Corp
# 30                  R.S Consultancy &amp; Services
# 31                                    Confidential
# 32        Dollarbird Information Services Pvt, Ltd
# 33                              Nikitha Palaparthi
# 34                          Independent Consultant
# 35                                 ASCO consulting
# 36                                         NY INST
# 37  3D India Staffing Research &amp; Consulting...
# 38                                     O.C. Tanner
# 39                                   Demand Matrix
# 40                             MADHUSUDHAN SRIDHAR
# 41                                  Suntech Global
# 42                        Strategic Consulting Lab
# 43                            Impel Labs Pvt. Ltd.
# 44                                    MRP Advisers
# 45                   Saras Solutions India Pvt Ltd
# 46                                     WildJasmine
# 47                             LNT Private Limited
#
#                                                Skills  \
# 0   Classic ASP Developer, Internet Marketing Prof...
# 1   .Net, Java, Data Science, Linux Administration...
# 2   Data Science, Artificial Intelligence, Machine...
# 3   Mean Stack, javascript, angularjs, mongodb, We...
# 4   Hadoop, Spark, Digital Strategy, Data Architec...
# 5   Analytics, Business Intelligence, Business Ana...
# 6                                        Data Science
# 7   Machine Learning, algorithms, Go Getter, Compu...
# 8   Technical Training, Software Development, Pres...
# 9   Software Development, It Sales, Account Manage...
# 10  Oracle Dba, Data Science, Data Warehousing, ET...
# 11  Qa, Ui/ux, Java Developer, Java Architect, C++...
# 12  Business Intelligence, Data Warehousing, Data ...
# 13  Office Administration, Hr Administration, tele...
# 14               Data Science, Python, Data Analytics
# 15  Social Media, digital media maketing, seo, smm...
# 16     Big Data, Hadoop, Data Analytics, Data Science
# 17  React.js, Data Science, Java, Front End, Busin...
# 18  Qlikview, Qlik Sense, Microsoft Azure, Power B...
# 19  Telecalling, Client Interaction, Marketing, Re...
# 20                                       Data Science
# 21  Corporate Sales, Software Development, Softwar...
# 22  Data Analytics, Data Science, Machine Learning...
# 23  Data Science, Machine Learning, Python, R, Dee...
# 24  Big Data, Data Science, Artificial Intelligenc...
# 25  Java, Net, Angularjs, Hr, Infrastructure, Mana...
# 26  Data Science, Artificial Intelligence, Machine...
# 27  Software Architecture, Vp Engineering, Product...
# 28  Data Science, Hadoop, Rpas, Devops, Python, Aw...
# 29  Signal Processing, Machine Learning, Neural Ne...
# 30  Web Technologies, Project Management, Software...
# 31  Server Administartion, Verilog, Vhdl, Digital ...
# 32  Data Analytics, Managed Services, Team Leading...
# 33  Ethical Hacking, Security Operations Center, S...
# 34  Data Science, Artificial Intelligence, analyti...
# 35  Machine Learning, Artificial Intelligence, Dat...
# 36  C, C++, Artificial Intelligence, Python, Php, ...
# 37  Relationship Management, Retail Sales, Private...
# 38                 Data Science, Software Engineering
# 39  Data Science, Big Data Analytics, Digital Mark...
# 40                  Data Science, Recruitment, Salary
# 41  B.Tech, Tableau, Statistics, R, Analytics, Tim...
# 42  Software Development, Business Intelligence, B...
# 43                   Data Science, Node.js, Angularjs
# 44  Data Science, Media Marketing, Resource Planni...
# 45  Data Analysis, Learning, Data Science, Compute...
# 46  Java, Hadoop, R, Machine Learning, Spark, Flum...
# 47  Software Development, Core Java, Unit Testing,...
#
#                     Location
# 0                      Delhi
# 1   Hyderabad / Secunderabad
# 2                       Pune
# 3                  Ahmedabad
# 4              UK - (london)
# 5          Vadodara / Baroda
# 6                    Chennai
# 7                 Trivandrum
# 8                     Indore
# 9      Bengaluru / Bangalore
# 10                 Hyderabad
# 11  Hyderabad / Secunderabad
# 12     Bengaluru / Bangalore
# 13                    Mumbai
# 14                    Mumbai
# 15  Hyderabad / Secunderabad
# 16                    Bhopal
# 17                Chandigarh
# 18                      Pune
# 19               Navi Mumbai
# 20                    Cochin
# 21                     Delhi
# 22  Hyderabad / Secunderabad
# 23                      Pune
# 24                      Pune
# 25                      Pune
# 26                      Pune
# 27     Bengaluru / Bangalore
# 28     Bengaluru / Bangalore
# 29                     Delhi
# 30     Bengaluru / Bangalore
# 31           Mysoru / Mysore
# 32  Hyderabad / Secunderabad
# 33     Bengaluru / Bangalore
# 34                 New Delhi
# 35                   Chennai
# 36                   Aligarh
# 37            Salt Lake City
# 38                      Pune
# 39     Bengaluru / Bangalore
# 40                    Mumbai
# 41                    Indore
# 42     Bengaluru / Bangalore
# 43                    MYSORE
# 44  Hyderabad / Secunderabad
# 45     Bengaluru / Bangalore
# 46                    Mumbai
# 47  Hyderabad / Secunderabad

# %%
driver.close()

# %% [markdown]
# 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey- compare/
#
# You have to find the following details:
#
# A) Book name
#
# B) Author name
#
# C) Volumes sold
#
# D) Publisher
#
# E) Genre

# %%
#connect to webdriver
driver=webdriver.Chrome(r'chromedriver.exe')
driver.maximize_window()

#get webpage
url=("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")
driver.get(url)
time.sleep(2)

# %%
Books=[]
Genre=[]

#scraping novels
try:
    Books_tag=driver.find_elements(By.XPATH,"//td[@class='left']")
    for i in Books_tag:
        Books.append(i.text)
except:
    Books.append("-")
    
#scraping novel's genre
try:
    Genre_tag=driver.find_elements(By.XPATH,"//td[@class='last left']")
    for i in Genre_tag:
        Genre.append(i.text)
except:
    Genre.append("-")

# %%
#slicing novels data
Book_name=Books[1::5]
Author_name=Books[2::5]
Volumes_sold=Books[3::5]
Publisher=Books[4::5]

# %%
#printing length
print(len(Book_name), len(Author_name),len(Volumes_sold), len(Publisher), len(Genre))
# Out:
# 100 100 100 100 100

# %%
#creating Dataframe
novels=pd.DataFrame({"Book Name":Book_name,"Author Name":Author_name,"Volumes Sold":Volumes_sold,"Publisher":Publisher,"Genre":Genre})
novels
# Out:
#                                             Book Name       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes Sold        Publisher                        Genre
# 0     5,094,805       Transworld  Crime, Thriller & Adventure
# 1     4,475,152       Bloomsbury           Children's Fiction
# 2     4,200,654       Bloomsbury           Children's Fiction
# 3     4,179,479       Bloomsbury           Children's Fiction
# 4     3,758,936     Random House              Romance & Sagas
# ..          ...              ...                          ...
# 95      807,311     Random House   General & Literary Fiction
# 96      794,201          Penguin        Food & Drink: General
# 97      792,187  Scholastic Ltd.          Young Adult Fiction
# 98      791,507            Orion           Biography: General
# 99      791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %%
driver.close()

# %% [markdown]
# 9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
#
# You have to find the following details:
#
# A) Name
#
# B) Year span
#
# C) Genre
#
# D) Run time
#
# E) Ratings
#
# F) Votes

# %%
#connect to webdriver
driver=webdriver.Chrome(r'chromedriver.exe')
driver.maximize_window()

#get webpage
url=("http://www.imdb.com/list/ls095964455/")
driver.get(url)
time.sleep(2)

# %%
Name= []
Year_span= []
Genre= []
Run_time= []
Ratings= []
Votes= []

#scraping series name
try:
    Name_tag= driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/a")
    for i in Name_tag:
        Name.append(i.text)
except NoSuchElementException as e:
    Name.append("--")

#scraping series Year span
try:
    Year_span_tag= driver.find_elements(By.XPATH,"//span[@class='lister-item-year text-muted unbold']")
    for i in Year_span_tag:
        Year_span.append(i.text)
except NoSuchElementException as e:
    Year_span.append("--") 
    
#scraping series Genre
try:
    Genre_tag= driver.find_elements(By.XPATH,"//span[@class='genre']")
    for i in Genre_tag:
        Genre.append(i.text)
except NoSuchElementException as e:
    Genre.append("--")
    
#scraping series Run Time
try:
    Run_time_tag= driver.find_elements(By.XPATH,"//span[@class='runtime']")
    for i in Run_time_tag:
        Run_time.append(i.text)
except NoSuchElementException as e:
    Run_time.append("--")
    
#scraping series Ratings
try:
    Ratings_tag= driver.find_elements(By.XPATH,"//span[@class='ipl-rating-star__rating']")
    for i in Ratings_tag[::23]:
        Ratings.append(i.text)
except NoSuchElementException as e:
    Ratings.append("--")
    
#scraping series Votes
try:
    Votes_tag= driver.find_elements(By.XPATH,"//span[@name='nv']")
    for i in Votes_tag:
        Votes.append(i.text)
except NoSuchElementException as e:
    Votes.append("--")
    
#printing length
print(len(Name), len(Year_span), len(Genre), len(Run_time), len(Ratings), len(Votes))
# Out:
# 100 100 100 100 100 100

# %%
#creating Dataframe
tv_series= pd.DataFrame({"Name":Name[:100],"Year span":Year_span[:100],"Genre":Genre[:100],"Run time":Run_time[:100],"Ratings":Ratings[:100],"Votes":Votes[:100]})
tv_series
# Out:
#                               Name    Year span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run time Ratings      Votes
# 0    57 min     9.2  2,049,894
# 1    51 min     8.7  1,145,639
# 2    44 min     8.1    968,424
# 3    60 min     7.5    288,868
# 4    43 min     7.6    248,444
# ..      ...     ...        ...
# 95   42 min     7.4     49,565
# 96   50 min     7.8     60,569
# 97   42 min     8.1    194,799
# 98   45 min     7.1     41,023
# 99  572 min     8.6    236,494
#
# [100 rows x 6 columns]

# %%
driver.close()

# %% [markdown]
# 10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
#
# You have to find the following details:
#
# A) Dataset name
#
# B) Data type
#
# C) Task
#
# D) Attribute type
#
# E) No of instances
#
# F) No of attribute
#
# G) Year
#
# Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
#connect to webdriver
driver=webdriver.Chrome(r'chromedriver.exe')
driver.maximize_window()

#get webpage
url=("https://archive.ics.uci.edu/")
driver.get(url)
time.sleep(2)

# %%
#clicking on view all Dataset
Dataset= driver.find_elements(By.XPATH,"//span[@class='normal']/b/a")[0].get_attribute('href')
driver.get(Dataset)

# %%
# Scraping dataset
data=[]
try:
    data_tag=driver.find_elements(By.XPATH,"//td//p[@class='normal']")
    for i in data_tag[8:4362]:
        data.append(i.text )
except:
    data.append('-')

# %%
#slicing dataset
Dataset_name=data[::7]
Data_type=data[1::7]
Task=data[2::7]
Attribute_type=data[3::7]
instances=data[4::7]
attribute=data[5::7]
Year=data[6::7]

# %%
#printing length
print(len(Dataset_name), len(Data_type), len(Task), len(Attribute_type), len(instances), len(attribute), len(Year))
# Out:
# 622 622 622 622 622 622 622

# %%
#creating Dataframe
Datasets= pd.DataFrame({"Dataset name":Dataset_name,"Data type":Data_type,"Task":Task,"Attribute type":Attribute_type,"Instances":instances,"Attribute":attribute,"Year":Year})
Datasets
# Out:
#                                           Dataset name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data type                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# 4                 Multivariate        Classification
# ..                          ...                   ...
# 617               Multivariate        Classification
# 618               Multivariate        Classification
# 619                                   Classification
# 620  Multivariate, Time-Series        Classification
# 621                 Univariate            Regression
#
#                   Attribute type Instances Attribute   Year
# 0    Categorical, Integer, Real      4177         8   1995
# 1          Categorical, Integer     48842        14   1996
# 2    Categorical, Integer, Real       798        38
# 3                   Categorical     37711       294   1998
# 4    Categorical, Integer, Real       452       279   1998
# ..                           ...       ...       ...    ...
# 617               Integer, Real     75840       525   2020
# 618               Integer, Real       400        50   2020
# 619                                  1014         7   2020
# 620                        Real     10129        16   2021
# 621                        Real      4000         2   2021
#
# [622 rows x 7 columns]

# %%
driver.close()
