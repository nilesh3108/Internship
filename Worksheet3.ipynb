# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\sony\anaconda3\lib\site-packages (4.4.3)
# Requirement already satisfied: trio~=0.17 in c:\users\sony\anaconda3\lib\site-packages (from selenium) (0.21.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\sony\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\sony\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\sony\anaconda3\lib\site-packages (from selenium) (2022.6.15)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\sony\anaconda3\lib\site-packages (from trio~=0.17->selenium) (20.3.0)
# Requirement already satisfied: outcome in c:\users\sony\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\users\sony\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: async-generator>=1.9 in c:\users\sony\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sniffio in c:\users\sony\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14; os_name == "nt" and implementation_name != "pypy" in c:\users\sony\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.3)
# Requirement already satisfied: sortedcontainers in c:\users\sony\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.2.2)
# Requirement already satisfied: wsproto>=0.14 in c:\users\sony\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6; extra == "socks" in c:\users\sony\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\sony\anaconda3\lib\site-packages (from cffi>=1.14; os_name == "nt" and implementation_name != "pypy"->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\sony\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\sony\Downloads\chromedriver.exe")

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
#question 1
driver.get("https://www.naukri.com/")
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div/div/div[5]/div/div/div[1]/input")
location.send_keys('Bangalore')
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi location']")    
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]//span') 
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
df=pd.DataFrame({'job_title':job_title,'job_location':job_location,'company_name':company_name,'Exp_required':experience_required})
df
# Out:
# 10 10 10 10
#                                          job_title  \
# 0       Business & Data Analyst- Assistant Manager
# 1                              Senior Data Analyst
# 2                              Senior Data Analyst
# 3                                 Sr. Data Analyst
# 4                         Sr Clinical Data Analyst
# 5                       Asst Clinical Data Analyst
# 6                                     Data Analyst
# 7                                     Data Analyst
# 8  Forecasting Analyst/ Data Scientist (US Client)
# 9                              Senior Data Analyst
#
#                                         job_location  \
# 0        Bangalore/Bengaluru, Hyderabad/Secunderabad
# 1               Bangalore/Bengaluru(Old Madras Road)
# 2                                Bangalore/Bengaluru
# 3                          Bangalore/Bengaluru, Pune
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# 6                     Bangalore/Bengaluru, Ahmedabad
# 7                                Bangalore/Bengaluru
# 8  Bangalore/Bengaluru, Gurgaon/Gurugram\n(WFH du...
# 9                                Bangalore/Bengaluru
#
#                               company_name Exp_required
# 0                             State Street      1-3 Yrs
# 1                                 KrazyBee      3-6 Yrs
# 2          Qualitest India Private Limited      5-8 Yrs
# 3  Global Indian School Education Services     6-11 Yrs
# 4                                  LabCorp      2-5 Yrs
# 5                                  LabCorp      1-3 Yrs
# 6     milestone internet marketing pvt ltd      2-7 Yrs
# 7                                    Bayer      2-5 Yrs
# 8                               Concentrix      3-8 Yrs
# 9                                    Optum      5-7 Yrs

# %%
#question 2
driver.get("https://www.naukri.com/")
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div/div/div[5]/div/div/div[1]/input")
location.send_keys('Bangalore')
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()
job_title=[]
job_location=[]
company_name=[]

title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi location']")    
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)

# %%
print(len(job_title),len(job_location),len(company_name))
df=pd.DataFrame({'job_title':job_title,'job_location':job_location,'company_name':company_name})
df
# Out:
# 10 10 10
#                                            job_title  \
# 0                                  Lead ML Scientist
# 1   Senior Manager - EmTech - Machine Learning - P&T
# 2                   Analystics & Modeling Specialist
# 3     Data scientist _Tata Consultancy Services(Tcs)
# 4  Job||Job Opening For AI Technologist - Data Sc...
# 5  Hiring For DATA Scientist @ NTT DATA Business ...
# 6                      Tcs Hiring For Data Scientist
# 7  Urgent Job Opening For AI Practitioner - Data ...
# 8                   Assistant Manager - Data Science
# 9                                     Data Scientist
#
#                                         job_location  \
# 0                        Bangalore/Bengaluru, Mumbai
# 1  Bangalore/Bengaluru, Mumbai, Hyderabad/Secunde...
# 2  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 3  Bangalore/Bengaluru, Kochi/Cochin, Indore, New...
# 4  Bangalore/Bengaluru, New Delhi, Hyderabad/Secu...
# 5  Bangalore/Bengaluru, Noida, Hyderabad/Secunder...
# 6   Bangalore/Bengaluru, Chennai, Mumbai (All Areas)
# 7  Bangalore/Bengaluru, Kochi/Cochin, New Delhi, ...
# 8                  Bangalore/Bengaluru, Mumbai, Pune
# 9  Bangalore/Bengaluru, New Delhi, Pune, Gurgaon/...
#
#                                   company_name
# 0                            Fractal Analytics
# 1                                          PwC
# 2                                    Accenture
# 3              TATA CONSULTANCY SERVICES (TCS)
# 4                                        Wipro
# 5  NTT DATA Business Solutions Private Limited
# 6              TATA CONSULTANCY SERVICES (TCS)
# 7                                        Wipro
# 8                                   CitiusTech
# 9                                ZS Associates

# %%
#question 3
driver.get("https://www.naukri.com/")
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi location']")    
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]//span') 
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
df=pd.DataFrame({'job_title':job_title,'job_location':job_location,'company_name':company_name,'Exp_required':experience_required})
df
# Out:
# 10 10 10 10
#                                            job_title  \
# 0   Senior Manager - EmTech - Machine Learning - P&T
# 1                   Analystics & Modeling Specialist
# 2     Data scientist _Tata Consultancy Services(Tcs)
# 3  Job||Job Opening For AI Technologist - Data Sc...
# 4  Hiring For DATA Scientist @ NTT DATA Business ...
# 5  Urgent Job Opening For AI Practitioner - Data ...
# 6                 Data Scientist / Sr Data Scientist
# 7                              Data Scientist Python
# 8                         Cloud Datascience Engineer
# 9                              Senior Data Scientist
#
#                                         job_location  \
# 0  Mumbai, Hyderabad/Secunderabad, Bangalore/Beng...
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...
# 2  Kochi/Cochin, Indore, New Delhi, Hyderabad/Sec...
# 3  New Delhi, Hyderabad/Secunderabad, Pune, Chenn...
# 4  Noida, Hyderabad/Secunderabad, Pune, Gurgaon/G...
# 5  Kochi/Cochin, New Delhi, Bangalore/Bengaluru, ...
# 6         Hyderabad/Secunderabad, Mumbai (All Areas)
# 7        Hyderabad/Secunderabad, Bangalore/Bengaluru
# 8  Noida, Hyderabad/Secunderabad, Bangalore/Benga...
# 9  Noida, Hyderabad/Secunderabad, Chennai, Bangal...
#
#                                   company_name Exp_required
# 0                                          PwC     5-12 Yrs
# 1                                    Accenture      6-8 Yrs
# 2              TATA CONSULTANCY SERVICES (TCS)     9-14 Yrs
# 3                                        Wipro     5-10 Yrs
# 4  NTT DATA Business Solutions Private Limited      4-9 Yrs
# 5                                        Wipro    11-20 Yrs
# 6                                          GEP      2-7 Yrs
# 7                                     Conduent      3-7 Yrs
# 8                                       Oracle     9-14 Yrs
# 9                                   InnovAccer      4-9 Yrs

# %%
#question 4
driver.get("https://www.flipkart.com/")
brand=driver.find_element(By.CLASS_NAME,"_3704LK")
brand.send_keys('sunglasses')
search=driver.find_element(By.CLASS_NAME,"_34RNph")
search.click()
brand_name=[]
product_description=[]
product_price=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[0:100]:
    brand=i.text
    brand_name.append(brand)
    
product_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in product_tags[0:100]:
    product=i.text
    product_description.append(product)
    
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')    
for i in price_tags[0:100]:
    price=i.text
    product_price.append(price)

# %%
print(len(brand_name),len(product_description),len(product_price))
df=pd.DataFrame({'brand_name':brand_name,'product_description':product_description,'product_price':product_price})
df
# Out:
# 40 40 40
#            brand_name                                product_description  \
# 0       VINCENT CHASE  by Lenskart Polarized, UV Protection Wayfarer ...
# 1        Silver Kartz           UV Protection Clubmaster Sunglasses (53)
# 2            Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 3            Fastrack   UV Protection Rectangular Sunglasses (Free Size)
# 4              PIRASO              UV Protection Aviator Sunglasses (54)
# 5              PIRASO          UV Protection Rectangular Sunglasses (52)
# 6              SUNBEE  UV Protection, Polarized Wayfarer Sunglasses (...
# 7       VINCENT CHASE  by Lenskart Polarized, UV Protection Cat-eye S...
# 8           Elligator                UV Protection Round Sunglasses (54)
# 9                SRPM             UV Protection Wayfarer Sunglasses (50)
# 10          New Specs   UV Protection Rectangular Sunglasses (Free Size)
# 11      VINCENT CHASE  by Lenskart UV Protection Aviator Sunglasses (53)
# 12          New Specs          UV Protection Oval Sunglasses (Free Size)
# 13         PHENOMENAL         UV Protection Retro Square Sunglasses (53)
# 14  SHAAH COLLECTIONS  UV Protection, Polarized, Mirrored Rectangular...
# 15      VINCENT CHASE  by Lenskart Polarized, UV Protection Aviator S...
# 16     ROZZETTA CRAFT  Polarized, Riding Glasses Sports, Wrap-around ...
# 17             PIRASO              UV Protection Aviator Sunglasses (58)
# 18              NuVew              UV Protection Aviator Sunglasses (57)
# 19        john jacobs                UV Protection Round Sunglasses (53)
# 20         LIZA ANGEL  Riding Glasses, Night Vision Spectacle Sunglas...
# 21     ROZZETTA CRAFT  UV Protection Retro Square Sunglasses (Free Size)
# 22             PIRASO              UV Protection Aviator Sunglasses (54)
# 23      VINCENT CHASE  by Lenskart Polarized, UV Protection Aviator S...
# 24            Dannilo            Others Spectacle Sunglasses (Free Size)
# 25           Fastrack          UV Protection Wrap-around Sunglasses (63)
# 26           Fastrack        UV Protection Shield Sunglasses (Free Size)
# 27      VINCENT CHASE  by Lenskart Polarized, UV Protection Round Sun...
# 28                 Mi           Polarized Aviator Sunglasses (Free Size)
# 29             SUNBEE  UV Protection, Polarized, Mirrored Retro Squar...
# 30         PHENOMENAL  UV Protection, Mirrored Retro Square Sunglasse...
# 31      VINCENT CHASE  by Lenskart Polarized, UV Protection Cat-eye S...
# 32         EYELLUSION  Riding Glasses, Riding Glasses, UV Protection ...
# 33     kingsunglasses  UV Protection, Mirrored Aviator Sunglasses (Fr...
# 34      VINCENT CHASE  by Lenskart Polarized, UV Protection Rectangul...
# 35       CRYSTAL CART  Polarized, UV Protection, Gradient, Riding Gla...
# 36          ROYAL SON  UV Protection, Gradient Butterfly Sunglasses (62)
# 37          Rich Club         UV Protection Retro Square Sunglasses (54)
# 38           Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...
# 39      VINCENT CHASE  by Lenskart Polarized, UV Protection Aviator S...
#
#    product_price
# 0           ₹749
# 1           ₹281
# 2           ₹799
# 3           ₹639
# 4           ₹224
# 5           ₹252
# 6           ₹283
# 7           ₹949
# 8           ₹298
# 9           ₹211
# 10          ₹264
# 11        ₹1,229
# 12          ₹207
# 13          ₹267
# 14          ₹195
# 15          ₹949
# 16          ₹499
# 17          ₹323
# 18          ₹198
# 19        ₹3,325
# 20          ₹199
# 21          ₹499
# 22          ₹221
# 23          ₹999
# 24          ₹170
# 25          ₹710
# 26          ₹719
# 27          ₹949
# 28          ₹799
# 29          ₹259
# 30          ₹350
# 31          ₹799
# 32          ₹199
# 33          ₹269
# 34          ₹749
# 35          ₹349
# 36          ₹664
# 37          ₹325
# 38          ₹719
# 39        ₹1,049

# %%
#question 5
driver.get("https://www.flipkart.com/")

# %%
product_rating=[]
review_summary=[]
full_review=[]

# %%
rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK"]')
for i in rating_tags[0:100]:
    rating=i.text
    product_rating.append(rating)
    
summary_tags=driver.find_elements(By.XPATH,"//span[@class='_2_R_DZ']")    
for i in summary_tags[0:100]:
    summary=i.text
    review_summary.append(summary)
    
review_tags=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]') 
for i in review_tags[0:100]:
    review=i.text
    full_review.append(review)

# %%
print(len(product_rating),len(review_summary),len(full_review))
# Out:
# 96 96 0

# %%
df=pd.DataFrame({'product_rating':product_rating,'review_summary':review_summary})
df
# Out:
#    product_rating                  review_summary
# 0             4.6  92,685 Ratings & 6,902 Reviews
# 1             4.6  92,685 Ratings & 6,902 Reviews
# 2             4.6  92,685 Ratings & 6,902 Reviews
# 3             4.6  92,685 Ratings & 6,902 Reviews
# 4             4.6  92,685 Ratings & 6,902 Reviews
# ..            ...                             ...
# 91            4.6  92,685 Ratings & 6,902 Reviews
# 92            4.6  92,685 Ratings & 6,902 Reviews
# 93            4.6  92,685 Ratings & 6,902 Reviews
# 94            4.6  92,685 Ratings & 6,902 Reviews
# 95            4.6  92,685 Ratings & 6,902 Reviews
#
# [96 rows x 2 columns]

# %%
#question 6
driver.get("https://www.flipkart.com/")

# %%
brand_name=[]
product_description=[]
selling_price=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[0:100]:
    brand=i.text
    brand_name.append(brand)
    
product_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa _2-ICcC"]')
for i in product_tags[0:100]:
    product=i.text
    product_description.append(product)
    
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')    
for i in price_tags[0:100]:
    price=i.text
    selling_price.append(price)

# %%
print(len(brand_name),len(product_description),len(selling_price))
# Out:
# 80 80 80

# %%
df=pd.DataFrame({'brand_name':brand_name,'product_description':product_description,'selling_price':selling_price})
df
# Out:
#     brand_name                                product_description  \
# 0       BRUTON             2 Combo Sneaker Shoes Sneakers For Men
# 1       BRUTON             2 Combo Sneaker Shoes Sneakers For Men
# 2       Chevit  Fashion Latest Combo Pack of 2 Pairs, Sneakers...
# 3       BRUTON             2 Combo Sneaker Shoes Sneakers For Men
# 4       BRUTON             2 Combo Sneaker Shoes Sneakers For Men
# ..         ...                                                ...
# 75      BRUTON             2 Combo Sneaker Shoes Sneakers For Men
# 76      AMFEET  Stylish Casual Sneaker Running Shoes for Men C...
# 77      AMFEET  Stylish Casual Sneaker Running Shoes for Men C...
# 78  Free Kicks  Combo of 2 FK - 411 & MCW145 Trendy Running Sh...
# 79      BRUTON             2 Combo Sneaker Shoes Sneakers For Men
#
#    selling_price
# 0           ₹764
# 1           ₹646
# 2           ₹699
# 3           ₹764
# 4           ₹646
# ..           ...
# 75          ₹764
# 76        ₹1,499
# 77        ₹1,499
# 78          ₹665
# 79          ₹764
#
# [80 rows x 3 columns]

# %%
#Question 7
driver.get("https://www.myntra.com/shoes")

# %%
shoe_brand=[]
shoe_description=[]
shoe_price=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[0:100]:
    brand=i.text
    shoe_brand.append(brand)
    
shoe_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa _2-ICcC"]')
for i in shoe_tags[0:100]:
    shoe=i.text
    show_description.append(shoe)
    
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')    
for i in price_tags[0:100]:
    price=i.text
    shoe_price.append(price)

# %%
print(len(shoe_brand),len(shoe_description),len(shoe_price))
# Out:
# 0 0 0

# %%
#question 8
driver.get("https://www.amazon.in/")

# %%
laptop_title=[]
laptop_rating=[]
laptop_price=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')
for i in title_tags[0:10]:
    title=i.text
    laptop_title.append(title)
    
rating_tags=driver.find_elements(By.XPATH,' //span[@class="a-size-base s-underline-text"]')
for i in rating_tags[0:10]:
    rating=i.text
    laptop_rating.append(rating)
    
price_tags=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')    
for i in price_tags[0:10]:
    price=i.text
    laptop_price.append(price)

# %%
print(len(laptop_title),len(laptop_rating),len(laptop_price))
# Out:
# 10 10 10

# %%
df=pd.DataFrame({'laptop_title':laptop_title,'laptop_rating':laptop_rating,'laptop_price':laptop_price})
df
# Out:
#                                         laptop_title laptop_rating  \
# 0  Samsung Galaxy Book2 Intel 12th Gen core i7 39...            26
# 1  Lenovo Ideapad Gaming 3 Intel Core i7 10th Gen...            23
# 2  HP Pavilion 14 12th Gen Intel Core i7 16GB SDR...            17
# 3  Hp Pavilion X360 11Th Gen Intel Core I7 14 Inc...            23
# 4  ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, I...            26
# 5  ASUS VivoBook K15 OLED (2021), 15.6-inch FHD O...            11
# 6  ASUS TUF Gaming F17 (2022), 17.3-inch (43.94 c...            17
# 7  Lenovo ThinkPad E14 Intel Core i7 11th Gen 14-...             3
# 8  ASUS TUF Gaming F15 (2022), 15.6-inch (39.62 c...            24
# 9  ASUS Zenbook 14 OLED (2022), 14" (35.56 cms) 2...            16
#
#   laptop_price
# 0       79,490
# 1       62,990
# 2       87,990
# 3       82,400
# 4       57,990
# 5       82,990
# 6     1,37,800
# 7       94,990
# 8     1,09,990
# 9     1,04,990

# %%
#question 9
driver.get("https://www.ambitionbox.com/")

# %%
job_title=[]
job_location=[]
company_name=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title noclick"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,"//div[@class='entity loc']")    
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//div[@class="company-info"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)

# %%
print(len(job_title),len(job_location),len(company_name))
df=pd.DataFrame({'job_title':job_title,'job_location':job_location,'company_name':company_name})
df
# Out:
# 10 10 10
#                                            job_title  \
# 0    Hiring Data Scientist #productbasecompany #CBRE
# 1  Hiring For Genpact-Data Scientist- Forecasting...
# 2  Genpact - Data Scientist - Forecasting/Python/...
# 3                                     Data Scientist
# 4                                     Data Scientist
# 5                                     Data Scientist
# 6                 Associate Manager - Data Scientist
# 7                                     Data Scientist
# 8                                     Data Scientist
# 9                   Data Scientist - Noida/Bangalore
#
#                                       job_location  \
# 0  Hyderabad/Secunderabad, Gurgaon/Gurugram, Noida
# 1  Hyderabad/Secunderabad, Gurgaon/Gurugram, Noida
# 2                                            Noida
# 3                                            Noida
# 4                                            Noida
# 5               Ghaziabad, Gurgaon/Gurugram, Noida
# 6                                            Noida
# 7                                            Noida
# 8                                            Noida
# 9              Chennai, Bengaluru/Bangalore, Noida
#
#                                         company_name
# 0  CBRE South Asia Pvt Ltd\n · \n4.3\nbased on 2....
# 1       CBRE South Asia Pvt Ltd\n4.3\n(2.3k Reviews)
# 2  GENPACT India Private Limited\n4.0\n(19.9k Rev...
# 3                      Genpact\n4.0\n(19.9k Reviews)
# 4  Ericsson India Global Services Pvt. Ltd.\n4.3\...
# 5  GENPACT India Private Limited\n4.0\n(19.9k Rev...
# 6  Optum Global Solutions (India) Private Limited...
# 7  Optum Global Solutions (India) Private Limited...
# 8  Ericsson India Global Services Pvt. Ltd.\n4.3\...
# 9    SOPRA STERIA INDIA LIMITED\n4.2\n(1.2k Reviews)

# %%
#question 10
driver.get("https://www.ambitionbox.com/")

# %%
company_name=[]
experience_required=[]
average_salary=[]
minimum_salary=[]
maximum_salary=[]
total_salary=[]

# %%
company_tags=driver.find_elements(By.XPATH,'//div[@class="company-info"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//div[@class="sbold-list-header"]') 
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)
    
average_tags=driver.find_elements(By.XPATH,'//p[@class="averageCtc"]')
for i in average_tags[0:10]:
    average=i.text
    average_salary.append(average)
    
maximum_tags=driver.find_elements(By.XPATH,'//div[@class="value body-medium"]') 
for i in maximum_tags[0:10]:
    maximum=i.text
    maximum_salary.append(maximum)
    
minimum_tags=driver.find_elements(By.XPATH,'//div[@class="salary-values"]') 
for i in minimum_tags[0:10]:
    minimum=i.text
    minimum_salary.append(minimum)
    
total_tags=driver.find_elements(By.XPATH,'//span[@class="datapoints"]')    
for i in total_tags[0:10]:
    total=i.text
    total_salary.append(total)

# %%
print(len(company_name),len(experience_required),len(average_salary),len(maximum_salary),len(minimum_salary),len(total_salary))
# Out:
# 10 10 10 10 10 10

# %%
df=pd.DataFrame({'company_name':company_name,'experience_required':experience_required,'average_salary':average_salary,'maximum_salary':maximum_salary,'minimum_salary':minimum_salary,'total_salary':total_salary})
df
# Out:
#                                         company_name  \
# 0  Walmart\nData Scientist Salary\n3-4 yrs experi...
# 1  Ab Inbev\nData Scientist Salary\n2-4 yrs exper...
# 2  Optum\nData Scientist Salary\n2-4 yrs experien...
# 3  ZS\nData Scientist Salary\n1-2 yrs experience ...
# 4  Fractal Analytics\nData Scientist Salary\n2-4 ...
# 5  Tiger Analytics\nData Scientist Salary\n2-4 yr...
# 6  Legato Health Technologies\nData Scientist Sal...
# 7  Tredence\nData Scientist Salary\n3 yrs experie...
# 8  UnitedHealth\nData Scientist Salary\n2-4 yrs e...
# 9  Ford Motor\nData Scientist Salary\n3-4 yrs exp...
#
#                           experience_required average_salary maximum_salary  \
# 0   3-4 yrs experience (based on 22 salaries)        ₹ 31.7L        ₹ 25.0L
# 1   2-4 yrs experience (based on 53 salaries)        ₹ 19.7L        ₹ 45.0L
# 2   2-4 yrs experience (based on 48 salaries)        ₹ 16.5L        ₹ 15.0L
# 3   1-2 yrs experience (based on 33 salaries)        ₹ 15.7L        ₹ 25.5L
# 4  2-4 yrs experience (based on 109 salaries)        ₹ 15.2L        ₹ 11.0L
# 5   2-4 yrs experience (based on 65 salaries)        ₹ 14.7L        ₹ 22.6L
# 6     4 yrs experience (based on 11 salaries)        ₹ 14.5L        ₹ 11.0L
# 7     3 yrs experience (based on 12 salaries)        ₹ 14.1L        ₹ 22.0L
# 8   2-4 yrs experience (based on 91 salaries)        ₹ 13.6L         ₹ 9.0L
# 9   3-4 yrs experience (based on 21 salaries)        ₹ 13.5L        ₹ 23.0L
#
#      minimum_salary             total_salary
# 0  ₹ 25.0L\n₹ 45.0L   (based on 22 salaries)
# 1  ₹ 15.0L\n₹ 25.5L   (based on 53 salaries)
# 2  ₹ 11.0L\n₹ 22.6L   (based on 48 salaries)
# 3  ₹ 11.0L\n₹ 22.0L   (based on 33 salaries)
# 4   ₹ 9.0L\n₹ 23.0L  (based on 109 salaries)
# 5   ₹ 9.0L\n₹ 20.0L   (based on 65 salaries)
# 6  ₹ 11.0L\n₹ 20.0L   (based on 11 salaries)
# 7   ₹ 8.8L\n₹ 17.5L   (based on 12 salaries)
# 8   ₹ 8.0L\n₹ 20.5L   (based on 91 salaries)
# 9  ₹ 10.0L\n₹ 18.0L   (based on 21 salaries)
